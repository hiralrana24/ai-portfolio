# %%
from mistralai import Mistral
print("Import successful!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mistralai import Mistral
#       2 print("Import successful!")
#
# ImportError: cannot import name 'Mistral' from 'mistralai' (unknown location)

# %%
import mistralai

print(dir(mistralai))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %%
from mistralai.client import Mistral
print("Import successful!")
# Out:
# Import successful!

# %%
client = Mistral(api_key="s46f3EZ1Up9LrY0INTDQ8wyGMSYggC05")

response = client.chat.complete(
    model="mistral-small-latest",
    messages=[{"role": "user", "content": "Explain what RAG is in 3 lines"}]
)

print(response.choices[0].message.content)
# Out:
# **RAG (Retrieval-Augmented Generation)** combines a retrieval system with a generative AI model to enhance responses. It first fetches relevant information from a knowledge source (like a database or documents) and then uses that data to generate more accurate, context-aware answers. This approach reduces hallucinations and improves reliability compared to standalone LLMs.
